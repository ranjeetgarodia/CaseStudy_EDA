# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# % matplotlib inline
# Out:
# UsageError: Line magic function `%` not found.

# %%
## data-set file
deaths_df = pd.read_csv('tb_deaths_100.csv',index_col=0,thousands=',').T ##ignore ',' if present in value for thousands(i.e.2,000)
existing_df = pd.read_csv('tb_existing_100.csv',index_col=0,thousands=',').T
new_df=pd.read_csv('tb_new_100.csv',index_col=0,thousands=',').T

# %%
print('deaths_df data ---')
print('deaths_df :: shape',deaths_df.shape)
deaths_df.head(2)
# Out:
# deaths_df data ---
# deaths_df :: shape (18, 207)
# TB mortality, all forms (per 100 000 population per year)  Afghanistan  \
# 1990                                                                50
# 1991                                                                49
#
# TB mortality, all forms (per 100 000 population per year)  Albania  Algeria  \
# 1990                                                             4        2
# 1991                                                             4        2
#
# TB mortality, all forms (per 100 000 population per year)  American Samoa  \
# 1990                                                                    5
# 1991                                                                    2
#
# TB mortality, all forms (per 100 000 population per year)  Andorra  Angola  \
# 1990                                                             4      60
# 1991                                                             4      60
#
# ...

# %%
print('existing_df dta ---')
existing_df.head(2)
# Out:
# existing_df dta ---
# TB prevalence, all forms (per 100 000 population per year) Afghanistan  \
# 1990                                                               436
# 1991                                                               429
#
# TB prevalence, all forms (per 100 000 population per year) Albania Algeria  \
# 1990                                                            42      45
# 1991                                                            40      44
#
# TB prevalence, all forms (per 100 000 population per year) American Samoa  \
# 1990                                                                   42
# 1991                                                                   14
#
# TB prevalence, all forms (per 100 000 population per year) Andorra Angola  \
# 1990                                                            39    514
# 1991                                                            37    514
#
# ...

# %%
print('new_df  data::')
new_df.head(2)
# Out:
# new_df  data::
# TB incidence, all forms (per 100 000 population per year) Afghanistan Albania  \
# 1990                                                              168      25
# 1991                                                              168      24
#
# TB incidence, all forms (per 100 000 population per year) Algeria  \
# 1990                                                           38
# 1991                                                           38
#
# TB incidence, all forms (per 100 000 population per year) American Samoa  \
# 1990                                                                  21
# 1991                                                                   7
#
# TB incidence, all forms (per 100 000 population per year) Andorra Angola  \
# 1990                                                           36    205
# 1991                                                           34    209
#
# ...

# %%
print('deaths_df shape::', deaths_df.shape)
print('existing_df  shape::', existing_df.shape)
print('new_df shape::',new_df.shape)
# Out:
# deaths_df shape:: (18, 207)
# existing_df  shape:: (18, 207)
# new_df shape:: (18, 208)

# %% [markdown]
# ### with above shape of data-set, means new_df have 1 extra column as compare to other data-set

# %%
## checking if any data-set have null values ?? if no index value , that means no na values 

print('deaths_df isna():: ', deaths_df.columns[deaths_df.isnull().any()]) 
print('existing_df isna()::', existing_df.columns[existing_df.isna().any()])
print('new_df isna()::,',new_df.columns[new_df.isnull().any()])
# Out:
# deaths_df isna()::  Index([], dtype='object', name='TB mortality, all forms (per 100 000 population per year)')
# existing_df isna():: Index([], dtype='object', name='TB prevalence, all forms (per 100 000 population per year)')
# new_df isna()::, Index(['Montenegro'], dtype='object', name='TB incidence, all forms (per 100 000 population per year)')

# %% [markdown]
# #### with above info, new_df have one column having na values with index/label  for 'Montenegro' country

# %%
new_df.loc[:,'Montenegro'] ## so this country most of data as Nan, so can ignore from our dataset
# Out:
# 1990    NaN
# 1991    NaN
# 1992    NaN
# 1993    NaN
# 1994    NaN
# 1995    NaN
# 1996    NaN
# 1997    NaN
# 1998    NaN
# 1999    NaN
# 2000    NaN
# 2001    NaN
# 2002    NaN
# 2003    NaN
# 2004    NaN
# 2005     33
# 2006     32
# 2007    NaN
# Name: Montenegro, dtype: object

# %% [markdown]
# #### we can easily observe that this country has most of the values as Nan, so we can remove this data from our data-set

# %%
### drop column 'Montenegro' from our data-set
new_df.drop(columns='Montenegro',inplace=True)
new_df.shape
# Out:
# (18, 207)

# %%
## checking if 'Montenegro' country is present in other data-set 
# deaths_df.loc['Montenegro' ==True]
print('Montenegro in deaths_df dataframe::', sum(deaths_df.index == 'Montenegro'))
print('deaths_df in existing_df dataframe::', sum(deaths_df.index =='Montenegro'))
# Out:
# Montenegro in deaths_df dataframe:: 0
# deaths_df in existing_df dataframe:: 0

# %% [markdown]
# #### since 'Montenegro' country data-set is not available in other data-set , so we are good here
# #### So now all 3 data-set have same number of Rows/columns

# %%
df_sum =deaths_df.describe()
df_sum
# Out:
# TB mortality, all forms (per 100 000 population per year)  Afghanistan  \
# count                                                        18.000000
# mean                                                         41.388889
# std                                                           6.491070
# min                                                          30.000000
# 25%                                                          36.250000
# 50%                                                          43.000000
# 75%                                                          46.750000
# max                                                          50.000000
#
# TB mortality, all forms (per 100 000 population per year)    Albania  Algeria  \
# count                                                      18.000000     18.0
# mean                                                        4.166667      2.0
# std                                                         0.618347      0.0
# ...

# %%
## lets look for pct change as mean, values are having much variations across all country 
existing_df_pct_change = existing_df.pct_change()
existing_df_pct_change
# Out:
# TB prevalence, all forms (per 100 000 population per year)  Afghanistan  \
# 1990                                                                NaN
# 1991                                                          -0.016055
# 1992                                                          -0.016317
# 1993                                                          -0.016588
# 1994                                                          -0.019277
# 1995                                                          -0.024570
# 1996                                                           0.000000
# 1997                                                          -0.025189
# 1998                                                          -0.033592
# 1999                                                          -0.002674
# 2000                                                          -0.072386
# 2001                                                          -0.057803
# ...

# %%
country_name=list(existing_df.columns.values)

# %%
existing_df_pct_change[existing_df_pct_change[country_name] > 0.0].head()
# Out:
# TB prevalence, all forms (per 100 000 population per year)  Afghanistan  \
# 1990                                                                NaN
# 1991                                                                NaN
# 1992                                                                NaN
# 1993                                                                NaN
# 1994                                                                NaN
#
# TB prevalence, all forms (per 100 000 population per year)  Albania  Algeria  \
# 1990                                                            NaN      NaN
# 1991                                                            NaN      NaN
# 1992                                                        0.02500      NaN
# 1993                                                        0.02439      NaN
# 1994                                                            NaN      NaN
#
# ...

# %%
## total countries 207
## here number of countries whose % change increase w.r.t year more than 8 out of total 15 years data
tt=(existing_df_pct_change[existing_df_pct_change[country_name] > 0.03].count() >8)
print(tt.sum())
list(existing_df_pct_change.columns[tt])
# Out:
# 25
# ['Azerbaijan',
#  'Botswana',
#  'Burkina Faso',
#  'Burundi',
#  'Chad',
#  'Congo, Rep.',
#  'Congo, Dem. Rep.',
#  'Equatorial Guinea',
#  'Ethiopia',
#  'Guinea',
#  'Guyana',
#  'Kenya',
#  'Lithuania',
#  'Mozambique',
#  'Nigeria',
#  'Moldova',
#  'Romania',
#  'Rwanda',
#  'Sierra Leone',
#  'Suriname',
#  'Tajikistan',
#  'Uganda',
#  'Ukraine',
#  'Tanzania',
#  'Zimbabwe']

# %% [markdown]
# ### above countries are those whose %change >0.03 in existing cases
# ###1 have taken threshold value as 0.03 , nearly 10% of total country
# ###2 have taken number of year count as 8 , atleast more than half of total year data

# %%
new_df_pct_change = new_df.pct_change()

# %%
new_tt =new_df_pct_change[new_df_pct_change.iloc[7:,:] >0.03].count() >4
print('below are the countries for whom %change >0.03 in the recent years ::',new_tt.sum())
list(new_df_pct_change.columns[new_tt])
# Out:
# below are the countries for whom %change >0.03 in the recent years :: 35
# ['American Samoa',
#  'Botswana',
#  'Burkina Faso',
#  'Burundi',
#  'Cameroon',
#  'Central African Republic',
#  'Chad',
#  'Congo, Rep.',
#  'Cook Islands',
#  "Cote d'Ivoire",
#  'Congo, Dem. Rep.',
#  'Equatorial Guinea',
#  'Ethiopia',
#  'French Polynesia',
#  'Gabon',
#  'Guinea',
#  'Guyana',
#  'Kazakhstan',
#  'Kenya',
#  'Lesotho',
#  'Mozambique',
#  'Namibia',
#  'Nauru',
#  'Nigeria',
#  'Palau',
#  'Romania',
#  'Rwanda',
#  'Sierra Leone',
#  'South Africa',
#  'Suriname',
#  'Swaziland',
#  'Tajikistan',
#  'Ukraine',
#  'Uzbekistan',
#  'Zimbabwe']

# %% [markdown]
# #### above are the countries for whom %change >0.03 in the recent years

# %%
new_df_pct_change.idxmin()
# Out:
# TB incidence, all forms (per 100 000 population per year)
# Afghanistan                 1991
# Albania                     2006
# Algeria                     1991
# American Samoa              1996
# Andorra                     1999
# Angola                      1998
# Anguilla                    2001
# Antigua and Barbuda         2007
# Argentina                   2005
# Armenia                     1991
# Australia                   1998
# Austria                     2007
# Azerbaijan                  1991
# Bahamas                     1991
# Bahrain                     1993
# Bangladesh                  2004
# Barbados                    1999
# Belarus                     1991
# Belgium                     2007
# Belize                      1991
# Benin                       1991
# Bermuda                     1999
# Bhutan                      1995
# Bolivia                     1996
# Bosnia and Herzegovina      2000
# Botswana                    2007
# ...

# %%
## finding in each year who has maximum % increase for new cases
new_df_pct_change.idxmax(axis=1) ## gives where max number of new TB cases in each year
# Out:
# 1990               NaN
# 1991      Cook Islands
# 1992      Cook Islands
# 1993             Palau
# 1994             Palau
# 1995           Tokelau
# 1996              Niue
# 1997    American Samoa
# 1998        Kazakhstan
# 1999      Cook Islands
# 2000             Nauru
# 2001      Cook Islands
# 2002              Niue
# 2003    American Samoa
# 2004      Cook Islands
# 2005             Palau
# 2006           Iceland
# 2007      Cook Islands
# dtype: object

# %% [markdown]
# ### seems Cook Islands , Palau are the two most increase in new_cases

# %%
#What about world trends? 
#What is following code doing?
#print (deaths_df)

death_total_year = deaths_df.sum(axis =1) ## adding w.r.t to each row as axis=1
existing_case_total_year = existing_df.sum(axis =1)
new_case_total_year = new_df.sum(axis=1)

total_cases_year = pd.DataFrame({'death_total': death_total_year,
                   'existing_case_total': existing_case_total_year,
                   'new_case_total': new_case_total_year },
                   index = death_total_year.index)
total_cases_year
# Out:
#       death_total  existing_case_total  new_case_total
# 1990         4938                40772         21855.0
# 1991         5108                40669         22288.0
# 1992         5194                39912         22421.0
# 1993         5372                39573         22836.0
# 1994         5471                39066         23177.0
# 1995         5655                38904         23639.0
# 1996         5502                37032         23878.0
# 1997         5658                37462         24608.0
# 1998         5666                36871         25154.0
# 1999         6074                37358         25884.0
# 2000         6019                36747         26464.0
# 2001         6198                36804         27065.0
# 2002         6074                37160         28188.0
# 2003         6087                36516         28192.0
# 2004         6042                36002         28352.0
# 2005         6051                35435         28219.0
# ...

# %% [markdown]
# ### plotting world trend eacn year cases

# %%
total_cases_year.plot(figsize=(12,6)).legend(
   loc='best')
plt.show()

# %% [markdown]
# #### it seems death_total is having very less value as compare to others so seems to consitent , so lets plot in otherway

# %%
fig,ax1 = plt.subplots()
ax1.plot(#total_cases_year.index,total_cases_year['existing_case_total'],
         #total_cases_year.index,total_cases_year['new_case_total'],
        total_cases_year.index,total_cases_year['death_total'])
#'new_case_total'
plt.show()

# %% [markdown]
# #### death_total is not constant as shown in above figure

# %%
death_country_mean = deaths_df.mean() ## will give mean for each country 
existing_country_mean = existing_df.mean()
new_cases_country_mean =new_df.mean()

# %%
death_country_mean_summary = death_country_mean.describe()
death_country_mean_summary
# Out:
# count    207.000000
# mean      27.659420
# std       38.687307
# min        0.000000
# 25%        2.972222
# 50%        9.666667
# 75%       41.333333
# max      222.166667
# dtype: float64

# %%
existing_country_mean_summary = existing_country_mean.describe()
existing_country_mean_summary
# Out:
# count     207.000000
# mean      181.398819
# std       200.832983
# min         2.444444
# 25%        30.861111
# 50%        85.611111
# 75%       333.555556
# max      1064.166667
# dtype: float64

# %%
new_cases_country_summary = new_cases_country_mean.describe()
new_cases_country_summary
# Out:
# count    208.000000
# mean     122.422543
# std      142.348002
# min        3.000000
# 25%       23.972222
# 50%       61.388889
# 75%      193.638889
# max      691.444444
# dtype: float64

# %%
death_outlier = death_country_mean_summary['50%']*5
print('death_outlier value::',death_outlier)
outlier_countries_by_deaths_index=death_country_mean >death_outlier
print('number of outlier countries for death count::',sum(outlier_countries_by_deaths_index))

existing_outlier = existing_country_mean_summary['50%']*5
print('existing_outlier value::',existing_outlier)
outlier_countries_by_existingcaes_index=existing_country_mean >existing_outlier
print('number of outlier countries for existing cases count::',sum(outlier_countries_by_existingcaes_index))

new_cases_country_outlier = new_cases_country_summary['50%']*5
print('new_cases_country_outlier value::',new_cases_country_outlier)
outlier_countries_by_newcases_index=new_cases_country_mean >new_cases_country_outlier
print('number of outlier countries for new cases count::',sum(outlier_countries_by_newcases_index))
# Out:
# death_outlier value:: 48.33333333333333
# number of outlier countries for death count:: 45
# existing_outlier value:: 428.05555555555554
# number of outlier countries for existing cases count:: 29
# new_cases_country_outlier value:: 306.94444444444446
# number of outlier countries for new cases count:: 22

# %%
## showing outlier country for death cases
deaths_df.T[outlier_countries_by_deaths_index].T.head() ## showing average number of death for outlier countries in each year
# Out:
# TB mortality, all forms (per 100 000 population per year)  Angola  Bangladesh  \
# 1990                                                           60          77
# 1991                                                           60          75
# 1992                                                           61          72
# 1993                                                           62          70
# 1994                                                           63          68
#
# TB mortality, all forms (per 100 000 population per year)  Bhutan  Botswana  \
# 1990                                                          101        46
# 1991                                                           95        51
# 1992                                                           90        55
# 1993                                                           85        58
# 1994                                                           81        61
#
# ...

# %%
outlier_death_df= deaths_df.T[outlier_countries_by_deaths_index].T
oulier_existing_df = existing_df.T[outlier_countries_by_existingcaes_index].T
outlier_new_df = new_df.T[outlier_countries_by_newcases_index].T

# %%
outlier_death_mean = outlier_death_df.mean(axis=1)
outlier_death_mean

avg_death_mean = deaths_df.T[-outlier_countries_by_deaths_index].T.mean(axis=1)
avg_death_mean

outlier_existing_mean = oulier_existing_df.mean(axis=1)
avg_existing_mean=existing_df.T[-outlier_countries_by_existingcaes_index].T.mean(axis=1)

outlier_new_mean = outlier_new_df.mean(axis=1)
avg_new_mean = new_df.T[-outlier_countries_by_newcases_index].T.mean(axis=1)

# %%
two_world_df = pd.DataFrame({ 
            'Average Better World Country': avg_death_mean,
            'Average Outlier Country' : outlier_death_mean},
        index = new_df.index)
two_world_df.plot(title="Estimated new TB cases per 100K",figsize=(12,8))
plt.title('average death cases trend per year ')
plt.show()

# %%
#two_world_df.pct_change().plot(title='',figsize=(12,8))

# %%
two_world_df = pd.DataFrame({ 
            'Average Better World Country': avg_existing_mean,
            'Average Outlier Country' : outlier_existing_mean},
        index = new_df.index)
two_world_df.plot(title="Estimated new TB cases per 100K",figsize=(12,8))
plt.title('average existing TB cases trend per year ')
plt.show()

# %%
two_world_df = pd.DataFrame({ 
            'Average Better World Country': avg_new_mean,
            'Average Outlier Country' : outlier_new_mean},
        index = new_df.index)
two_world_df.plot(title="Estimated new TB cases per 100K",figsize=(12,8))
plt.title('average new TB cases trend per year')
plt.show()
